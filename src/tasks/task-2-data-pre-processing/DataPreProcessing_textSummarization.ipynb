# %%
import numpy as np
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
df = pd.read_csv('chunk4.csv')

# %%
df1_lower = df.copy()
df1_lower[['article','summary']] = df[['article','summary']].applymap(lambda x: x.lower())
df1_lower.head()
# Out:
#                                              article  \
# 0  by . jonathan petre . and jo knowsley . warnin...
# 1  an austrian girl has said she feels she 'can r...
# 2  british muslims are being urged to wear a new ...
# 3  by . associated press reporter . officials say...
# 4  more issues in ferguson: former ferguson, miss...
#
#                                              summary
# 0  education secretary michael gove warned about ...
# 1  sabina selimovic spoke via text message to par...
# 2  £22 headscarf is backed by muslim groups as a ...
# 3  a woman's body was found on mount rainer sunda...
# 4  jaris hayden, 29, will be arraigned december 3...

# %% [markdown]
# # Remove punctuations

# %%
#remove punctuation
df1_lower[['article','summary']] = df[['article','summary']].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '' , str(x)))
df1_lower.head()

# %% [markdown]
# # Remove Stopwords

# %%
stop_words = set(stopwords.words('english'))
stop_words.add('subject')
stop_words.add('http')
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])
df1_lower[['article','summary']] = df[['article','summary']].apply(lambda x: remove_stopwords(x))
df1_lower.head()
# Out:
#                                              article  \
# 0  0 By . Jonathan Petre . Jo Knowsley . Warnin.....
# 1  0 By . Jonathan Petre . Jo Knowsley . Warnin.....
# 2  0 By . Jonathan Petre . Jo Knowsley . Warnin.....
# 3  0 By . Jonathan Petre . Jo Knowsley . Warnin.....
# 4  0 By . Jonathan Petre . Jo Knowsley . Warnin.....
#
#                                              summary
# 0  0 Education Secretary Michael Gove warned ... ...
# 1  0 Education Secretary Michael Gove warned ... ...
# 2  0 Education Secretary Michael Gove warned ... ...
# 3  0 Education Secretary Michael Gove warned ... ...
# 4  0 Education Secretary Michael Gove warned ... ...

# %% [markdown]
# # Rephrase text

# %%
df1_lower["article"] = df1_lower["article"].apply(lambda x: re.sub('b[w-]+?@w+?.w{2,4}b', 'emailadd',x))
#url
df1_lower["article"] = df1_lower["article"].apply(lambda x:re.sub('(http[s]?S+)|(w+.[A-Za-z]{2,4}S*)', 'urladd', x))
df1_lower.head()
# Out:
#                                              article  \
# 0  0 0 by jonathan petr an jo knourladd ... 1 0 b...
# 1  0 0 by jonathan petr an jo knourladd ... 1 0 b...
# 2  0 0 by jonathan petr an jo knourladd ... 1 0 b...
# 3  0 0 by jonathan petr an jo knourladd ... 1 0 b...
# 4  0 0 by jonathan petr an jo knourladd ... 1 0 b...
#
#                                              summary
# 0  0 0 eucat secretari michael gove urladd... 1 0...
# 1  0 0 eucat secretari michael gove urladd... 1 0...
# 2  0 0 eucat secretari michael gove urladd... 1 0...
# 3  0 0 eucat secretari michael gove urladd... 1 0...
# 4  0 0 eucat secretari michael gove urladd... 1 0...

# %%
df1_lower["summary"] = df1_lower["summary"].apply(lambda x: re.sub('b[w-]+?@w+?.w{2,4}b', 'emailadd',x))
#url
df1_lower["summary"] = df1_lower["summary"].apply(lambda x:re.sub('(http[s]?S+)|(w+.[A-Za-z]{2,4}S*)', 'urladd', x))
df1_lower.head()
# Out:
#                                              article  \
# 0  0 0 by jonathan petr an jo knowsley ... 1 0 by...
# 1  0 0 by jonathan petr an jo knowsley ... 1 0 by...
# 2  0 0 by jonathan petr an jo knowsley ... 1 0 by...
# 3  0 0 by jonathan petr an jo knowsley ... 1 0 by...
# 4  0 0 by jonathan petr an jo knowsley ... 1 0 by...
#
#                                              summary
# 0  0 0 eucat secretari michael gove urladd... 1 0...
# 1  0 0 eucat secretari michael gove urladd... 1 0...
# 2  0 0 eucat secretari michael gove urladd... 1 0...
# 3  0 0 eucat secretari michael gove urladd... 1 0...
# 4  0 0 eucat secretari michael gove urladd... 1 0...

# %% [markdown]
# # Remove words and digits containing digits

# %%
df1_lower[['article','summary']] = df1_lower[['article','summary']].apply(lambda x: re.sub('W*dw*','',str(x)))
df1_lower.head()
# Out:
#                                              article  \
# 0  0        0        By  Jonathan Petre  an Jo Kn...
# 1  0        0        By  Jonathan Petre  an Jo Kn...
# 2  0        0        By  Jonathan Petre  an Jo Kn...
# 3  0        0        By  Jonathan Petre  an Jo Kn...
# 4  0        0        By  Jonathan Petre  an Jo Kn...
#
#                                              summary
# 0  0        0        Eucation Secretary Michael G...
# 1  0        0        Eucation Secretary Michael G...
# 2  0        0        Eucation Secretary Michael G...
# 3  0        0        Eucation Secretary Michael G...
# 4  0        0        Eucation Secretary Michael G...

# %% [markdown]
# # Stemming and Lemmatization

# %% [markdown]
# **#stemming**

# %%
stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])
df1_lower["article"] = df1_lower["article"].apply(lambda x: stem_words(x))
df1_lower["summary"] = df1_lower["summary"].apply(lambda x: stem_words(x))

# %% [markdown]
# #Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
df1_lower["article"] = df1_lower["article"].apply(lambda text: lemmatize_words(text))
df1_lower["summary"] = df1_lower["summary"].apply(lambda text: lemmatize_words(text))

# %% [markdown]
# # Remove Extra Spaces

# %%
df1_lower["article"] = df1_lower["article"].apply(lambda text: re.sub(' +', ' ', str(text)))
df1_lower["summary"] = df1_lower["summary"].apply(lambda text: re.sub(' +', ' ', str(text)))
